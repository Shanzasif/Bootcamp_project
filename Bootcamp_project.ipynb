# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /users/snasif/.venv/auto_python_3.11.11_data_science_2025.08.21/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: bleach in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: jupytext in /users/snasif/.venv/auto_python_3.11.11_data_science_2025.08.21/lib/python3.11/site-packages (from kaggle) (1.19.3)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.27 in /users/snasif/.venv/auto_python_3.11.11_data_science_2025.08.21/lib/python3.11/site-packages (from kaggle) (0.1.28)
# Requirement already satisfied: packaging in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from kaggle) (25.0)
# Requirement already satisfied: protobuf in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from kaggle) (6.32.0)
# Requirement already satisfied: python-dateutil in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /users/snasif/.venv/auto_python_3.11.11_data_science_2025.08.21/lib/python3.11/site-packages (from kaggle) (1.2.2)
# Requirement already satisfied: python-slugify in /users/snasif/.venv/auto_python_3.11.11_data_science_2025.08.21/lib/python3.11/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: tqdm in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jupytext->kaggle) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /users/snasif/.venv/auto_python_3.11.11_data_science_2025.08.21/lib/python3.11/site-packages (from jupytext->kaggle) (0.6.1)
# Requirement already satisfied: nbformat in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jupytext->kaggle) (6.0.2)
# Requirement already satisfied: six>=1.5 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /users/snasif/.venv/auto_python_3.11.11_data_science_2025.08.21/lib/python3.11/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from requests->kaggle) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from requests->kaggle) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from requests->kaggle) (2025.8.3)
# Requirement already satisfied: mdurl~=0.1 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from nbformat->jupytext->kaggle) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from nbformat->jupytext->kaggle) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from nbformat->jupytext->kaggle) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.27.0)
# Requirement already satisfied: platformdirs>=2.5 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.3.8)
# Requirement already satisfied: typing-extensions>=4.4.0 in /hpc/m3/python/3.11.11/data_science-2025.08.21/lib/python3.11/site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat->jupytext->kaggle) (4.14.1)
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /users/snasif/.local/lib/python3.11/site-packages (26.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('merged_data.csv', on_bad_lines='skip', engine='python')
print(f"Loaded {len(df)} rows")
# Out:
# Loaded 730075 rows

# %%
df
# Out:
#         Unnamed: 0                        title  rank        date  \
# 0                0      Chantaje (feat. Maluma)     1  2017-01-01
# 1                1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2                2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                3                       Safari     4  2017-01-01
# 4                4                  Shaky Shaky     5  2017-01-01
# ...            ...                          ...   ...         ...
# 730070      730070                           不該   167  2020-05-05
# 730071      730071                 WHATS POPPIN   168  2020-05-05
# 730072      730072                          擋一根   169  2020-05-05
# 730073      730073                       愛情怎麼了嗎   170  2020-05-05
# 730074      730074                          家家酒   171  2020-05-05
#
#                                        artist  \
# 0                                     Shakira
# 1                                Ricky Martin
# 2                                        CNCO
# 3       J Balvin, Pharrell Williams, BIA, Sky
# 4                                Daddy Yankee
# ...                                       ...
# 730070                  Jay Chou, A-Mei Chang
# 730071                            Jack Harlow
# 730072                             Bisiugroup
# 730073                               Crowd Lu
# 730074                                Jia Jia
#
#                                                       url     region   chart  \
# 0       https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1       https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2       https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3       https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4       https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
# ...                                                   ...        ...     ...
# 730070  https://open.spotify.com/track/7LyCtbxher5m97M...     Taiwan  top200
# 730071  https://open.spotify.com/track/1jaTQ3nqY3oAAYy...     Taiwan  top200
# 730072  https://open.spotify.com/track/6439IQyiZV5I7aO...     Taiwan  top200
# 730073  https://open.spotify.com/track/5ZaPc3ILOQT4Qc2...     Taiwan  top200
# 730074  https://open.spotify.com/track/6mO5fCJKvB9tr5R...     Taiwan  top200
#
#                 trend   streams  ... af_key af_loudness  af_mode  \
# 0       SAME_POSITION  253019.0  ...    8.0      -2.921      0.0
# 1             MOVE_UP  223988.0  ...   11.0      -4.070      0.0
# 2           MOVE_DOWN  210943.0  ...    4.0      -3.073      0.0
# 3       SAME_POSITION  173865.0  ...    0.0      -4.361      1.0
# 4             MOVE_UP  153956.0  ...    6.0      -4.228      0.0
# ...               ...       ...  ...    ...         ...      ...
# 730070        MOVE_UP    5908.0  ...    4.0      -6.609      1.0
# 730071        MOVE_UP    5855.0  ...   11.0      -6.671      0.0
# 730072  SAME_POSITION    5844.0  ...    6.0      -6.412      0.0
# 730073        MOVE_UP    5844.0  ...    8.0      -8.471      1.0
# 730074      MOVE_DOWN    5838.0  ...    6.0      -6.272      1.0
#
#         af_speechiness af_acousticness af_instrumentalness af_liveness  \
# 0               0.0776         0.18700            0.000030      0.1590
# 1               0.2260         0.00431            0.000017      0.1010
# 2               0.0502         0.40000            0.000000      0.1760
# 3               0.3260         0.55100            0.000003      0.1260
# 4               0.2920         0.07600            0.000000      0.0631
# ...                ...             ...                 ...         ...
# 730070          0.0293         0.19000            0.000000      0.1180
# 730071          0.2450         0.01700            0.000000      0.2720
# 730072          0.0452         0.07990            0.000000      0.0980
# 730073          0.0558         0.73400            0.000000      0.0801
# 730074          0.0277         0.42100            0.000000      0.1070
#
#         af_valence  af_tempo  af_time_signature
# 0            0.907   102.034                4.0
# 1            0.533    99.935                4.0
# 2            0.710    93.974                4.0
# 3            0.555   180.044                4.0
# 4            0.873    88.007                4.0
# ...            ...       ...                ...
# 730070       0.187    75.027                4.0
# 730071       0.826   145.062                4.0
# 730072       0.430    76.064                4.0
# 730073       0.184   129.913                4.0
# 730074       0.181   132.103                4.0
#
# [730075 rows x 29 columns]

# %%
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (730075, 29)
# ['Unnamed: 0', 'title', 'rank', 'date', 'artist', 'url', 'region', 'chart', 'trend', 'streams', 'track_id', 'album', 'popularity', 'duration_ms', 'explicit', 'release_date', 'available_markets', 'af_danceability', 'af_energy', 'af_key', 'af_loudness', 'af_mode', 'af_speechiness', 'af_acousticness', 'af_instrumentalness', 'af_liveness', 'af_valence', 'af_tempo', 'af_time_signature']
#    Unnamed: 0                        title  rank        date  \
# 0           0      Chantaje (feat. Maluma)     1  2017-01-01
# 1           1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2           2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3           3                       Safari     4  2017-01-01
# 4           4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams  ... af_key af_loudness  af_mode  af_speechiness  \
# 0  SAME_POSITION  253019.0  ...    8.0      -2.921      0.0          0.0776
# 1        MOVE_UP  223988.0  ...   11.0      -4.070      0.0          0.2260
# 2      MOVE_DOWN  210943.0  ...    4.0      -3.073      0.0          0.0502
# 3  SAME_POSITION  173865.0  ...    0.0      -4.361      1.0          0.3260
# 4        MOVE_UP  153956.0  ...    6.0      -4.228      0.0          0.2920
#
#   af_acousticness af_instrumentalness af_liveness  af_valence  af_tempo  \
# 0         0.18700            0.000030      0.1590       0.907   102.034
# 1         0.00431            0.000017      0.1010       0.533    99.935
# 2         0.40000            0.000000      0.1760       0.710    93.974
# 3         0.55100            0.000003      0.1260       0.555   180.044
# 4         0.07600            0.000000      0.0631       0.873    88.007
#
#    af_time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
#
# [5 rows x 29 columns]

# %%
print(df['region'].unique())
print(df['date'].min(), df['date'].max())
print(df['region'].nunique(), "regions total")
# Out:
# ['Argentina' 'Australia' 'Brazil' 'Austria' 'Belgium' 'Colombia' 'Bolivia'
#  'Denmark' 'Bulgaria' 'Canada' 'Chile' 'Costa Rica' 'Czech Republic'
#  'Finland' 'Dominican Republic' 'Ecuador' 'El Salvador' 'Estonia' 'France'
#  'Germany' 'Global' 'Greece' 'Guatemala' 'Honduras' 'Hong Kong' 'Hungary'
#  'Iceland' 'Indonesia' 'Ireland' 'Italy' 'Japan' 'Latvia' 'Lithuania'
#  'Malaysia' 'Luxembourg' 'Mexico' 'Netherlands' 'New Zealand' 'Nicaragua'
#  'Norway' 'Panama' 'Paraguay' 'Peru' 'Philippines' 'Poland' 'Portugal'
#  'Singapore' 'Spain' 'Slovakia' 'Sweden' 'Taiwan' 'Switzerland' 'Turkey'
#  'United Kingdom' 'United States' 'Uruguay' 'Thailand' 'Andorra' 'Romania'
#  'Vietnam' 'Egypt' 'India' 'Israel' 'Morocco' 'Saudi Arabia'
#  'South Africa' 'United Arab Emirates']
# 2017-01-01 2021-10-15
# 67 regions total

# %%
print(df['date'].min(), df['date'].max())
# Out:
# 2017-01-01 2021-10-15

# %%
european_countries = [
    'United Kingdom', 'Germany', 'France', 'Spain', 'Italy',
    'Netherlands', 'Sweden', 'Norway', 'Denmark', 'Finland',
    'Belgium', 'Austria', 'Switzerland', 'Poland', 'Portugal',
    'Czech Republic', 'Hungary', 'Romania', 'Greece', 'Ireland',
    'Bulgaria', 'Slovakia', 'Estonia', 'Latvia', 'Lithuania',
    'Luxembourg', 'Iceland'
]

# %%
# Filter to European countries only
df_europe = df[df['region'].isin(european_countries)].copy()

# %%
# Convert date to datetime
df_europe['date'] = pd.to_datetime(df_europe['date'])

# %%
# Add a year column for grouping
df_europe['year'] = df_europe['date'].dt.year

# %%
print(df_europe.shape)
print(df_europe['year'].value_counts().sort_index())
# Out:
# (307903, 30)
# year
# 2017    172888
# 2018     93502
# 2019         6
# 2020     41479
# 2021        28
# Name: count, dtype: int64

# %%
# Check what's going on with 2019 and 2021
print(df_europe[df_europe['year'] == 2019][['date', 'region', 'title']].head(10))
print()
print(df_europe[df_europe['year'] == 2021][['date', 'region', 'title']].head(10))
# Out:
#              date    region       title
# 62401  2019-09-13  Portugal     Ride It
# 62557  2019-09-13   Romania      Ransom
# 62715  2019-05-28     Italy    Io e lei
# 63086  2019-05-28    Latvia  Siren Song
# 210203 2019-07-30   Ireland      Africa
# 212942 2019-09-13     Italy      Lalala
#
#              date region                                              title
# 71618  2021-09-10  Spain                                              París
# 478897 2021-10-15  Spain                                    Poblado - Remix
# 478898 2021-10-15  Spain  No Me Conocen (Remix) [con DUKI, Rei & Tiago PZK]
# 478899 2021-10-15  Spain                            Wow Wow (feat. Becky G)
# 478900 2021-10-15  Spain                                          40 NOCHES
# 478901 2021-10-15  Spain                                            Me Fije
# 478902 2021-10-15  Spain                                      Mares De Miel
# 478903 2021-10-15  Spain                                            YaMeFui
# 478904 2021-10-15  Spain                                 LA NOCHE DE ANOCHE
# 478905 2021-10-15  Spain                                               Ella

# %%
import os
os.makedirs('figures', exist_ok=True)

# %%
import matplotlib.pyplot as plt #initial plot

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for ax, col, label in zip(axes, ['af_energy', 'af_valence'], ['Energy', 'Valence (Happiness)']):
    for year, color in zip([2017, 2018, 2020], ['blue', 'green', 'red']):
        subset = df_europe[df_europe['year'] == year][col]
        subset.plot.kde(ax=ax, label=str(year), color=color)
    ax.set_title(f'{label} Distribution by Year')
    ax.legend()
    ax.set_xlabel(col)

plt.tight_layout()
plt.savefig('figures/energy_valence_distributions.png', dpi=150)
plt.show()

# %%
# Calculate mean energy and valence by year
summary = df_europe.groupby('year')[['af_energy', 'af_valence']].mean().round(3)
print(summary)
# Out:
#       af_energy  af_valence
# year
# 2017      0.669       0.480
# 2018      0.665       0.485
# 2019      0.574       0.524
# 2020      0.634       0.508
# 2021      0.637       0.605

# %%
# Monthly trend through 2020
df_2020 = df_europe[df_europe['year'] == 2020].copy()
df_2020['month'] = df_2020['date'].dt.month

monthly = df_2020.groupby('month')[['af_energy', 'af_valence']].mean().round(3)
print(monthly)
# Out:
#        af_energy  af_valence
# month
# 5          0.629       0.501
# 6          0.639       0.518

# %%
print(df_europe[df_europe['year'] == 2020]['date'].sort_values().unique())
# Out:
# <DatetimeArray>
# ['2020-05-01 00:00:00', '2020-05-02 00:00:00', '2020-05-03 00:00:00',
#  '2020-05-04 00:00:00', '2020-05-05 00:00:00', '2020-05-06 00:00:00',
#  '2020-06-01 00:00:00', '2020-06-02 00:00:00', '2020-06-03 00:00:00',
#  '2020-06-04 00:00:00', '2020-06-05 00:00:00', '2020-06-06 00:00:00']
# Length: 12, dtype: datetime64[ns]

# %% [markdown]
# # Pivot!!!!

# %%
df_europe = df_europe[df_europe['year'].isin([2017, 2018])].copy()
print(df_europe.shape)
print(df_europe['year'].value_counts())
# Out:
# (266390, 30)
# year
# 2017    172888
# 2018     93502
# Name: count, dtype: int64

# %%
# Average audio features by country
country_avg = df_europe.groupby('region')[['af_energy', 'af_valence', 'af_danceability', 'af_acousticness']].mean().round(3)
country_avg = country_avg.sort_values('af_energy', ascending=False)
print(country_avg)
# Out:
#                 af_energy  af_valence  af_danceability  af_acousticness
# region
# Finland             0.715       0.506            0.662            0.154
# Spain               0.700       0.558            0.680            0.221
# Hungary             0.692       0.493            0.671            0.162
# Germany             0.690       0.483            0.683            0.175
# Austria             0.686       0.483            0.676            0.176
# Italy               0.685       0.482            0.658            0.193
# Netherlands         0.677       0.509            0.692            0.205
# Czech Republic      0.674       0.466            0.654            0.173
# Slovakia            0.672       0.461            0.668            0.164
# Switzerland         0.671       0.478            0.679            0.196
# United Kingdom      0.663       0.491            0.654            0.187
# France              0.661       0.486            0.709            0.278
# Bulgaria            0.660       0.459            0.690            0.144
# Luxembourg          0.659       0.510            0.647            0.211
# Poland              0.659       0.470            0.665            0.204
# Ireland             0.658       0.482            0.653            0.193
# Romania             0.658       0.427            0.696            0.182
# Greece              0.658       0.457            0.685            0.158
# Belgium             0.658       0.467            0.672            0.214
# Estonia             0.657       0.440            0.667            0.169
# Sweden              0.655       0.463            0.642            0.203
# Norway              0.654       0.454            0.650            0.198
# Latvia              0.653       0.437            0.680            0.171
# Lithuania           0.651       0.454            0.675            0.176
# Denmark             0.636       0.487            0.686            0.224
# Portugal            0.635       0.480            0.675            0.237
# Iceland             0.616       0.469            0.709            0.186

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 1, figsize=(14, 10))

energy_order = country_avg.sort_values('af_energy', ascending=True).index

for ax, col, label, color in zip(
    axes,
    ['af_energy', 'af_valence'],
    ['Energy', 'Valence (Happiness)'],
    ['orange', 'green']
):
    ax.barh(energy_order, country_avg.loc[energy_order, col], color=color)
    ax.set_title(f'Average {label} of Top Charting Songs by European Country (2017-2018)')
    ax.set_xlabel(label)
    ax.axvline(country_avg[col].mean(), color='black', linestyle='--', label='Average')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(country_avg['af_energy'], country_avg['af_valence'], color='pink', s=100, zorder=3)

# Label each country dot
for country, row in country_avg.iterrows():
    ax.annotate(country, (row['af_energy'], row['af_valence']),
                textcoords="offset points", xytext=(6, 3), fontsize=10)

# Draw quadrant lines at the midpoint
ax.axhline(country_avg['af_valence'].mean(), color='gray', linestyle='--', alpha=0.5)
ax.axvline(country_avg['af_energy'].mean(), color='gray', linestyle='--', alpha=0.5)

# Label quadrants
ax.text(0.71, 0.54, 'High Energy\nHappy', fontsize=13, color='green', fontweight='bold')
ax.text(0.71, 0.43, 'High Energy\nIntense', fontsize=13, color='red', fontweight='bold')
ax.text(0.615, 0.54, 'Chill\nHappy', fontsize=13, color='blue', fontweight='bold')
ax.text(0.615, 0.43, 'Chill\nMelancholic', fontsize=13, color='purple', fontweight='bold')

ax.set_xlabel('Average Energy', fontsize=13)
ax.set_ylabel('Average Valence (Happiness)', fontsize=12)
ax.set_title('European Countries by Musical Mood (2017-2018)', fontsize=14)

plt.tight_layout()
plt.show()

# %%
country_avg['mood_score'] = ((country_avg['af_energy'] + country_avg['af_valence']) / 2).round(3)
print(country_avg[['af_energy', 'af_valence', 'mood_score']].sort_values('mood_score', ascending=False))
# Out:
#                 af_energy  af_valence  mood_score
# region
# Spain               0.700       0.558       0.629
# Finland             0.715       0.506       0.610
# Netherlands         0.677       0.509       0.593
# Hungary             0.692       0.493       0.592
# Germany             0.690       0.483       0.586
# Austria             0.686       0.483       0.584
# Italy               0.685       0.482       0.584
# Luxembourg          0.659       0.510       0.584
# United Kingdom      0.663       0.491       0.577
# France              0.661       0.486       0.574
# Switzerland         0.671       0.478       0.574
# Ireland             0.658       0.482       0.570
# Czech Republic      0.674       0.466       0.570
# Slovakia            0.672       0.461       0.566
# Poland              0.659       0.470       0.564
# Belgium             0.658       0.467       0.562
# Denmark             0.636       0.487       0.562
# Bulgaria            0.660       0.459       0.560
# Sweden              0.655       0.463       0.559
# Portugal            0.635       0.480       0.558
# Greece              0.658       0.457       0.558
# Norway              0.654       0.454       0.554
# Lithuania           0.651       0.454       0.552
# Estonia             0.657       0.440       0.548
# Latvia              0.653       0.437       0.545
# Romania             0.658       0.427       0.542
# Iceland             0.616       0.469       0.542

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Download world map
world = gpd.read_file("https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip")

# Fix name mismatches
country_avg_reset = country_avg.reset_index()
country_avg_reset['region_fixed'] = country_avg_reset['region'].replace({'Czech Republic': 'Czechia'})

# Merge
europe_map = world[world['CONTINENT'] == 'Europe'].copy()
europe_map = europe_map.merge(
    country_avg_reset[['region_fixed', 'mood_score']],
    left_on='NAME', right_on='region_fixed', how='left'
)

# Plot
fig, ax = plt.subplots(1, 1, figsize=(14, 10))
europe_map.plot(
    column='mood_score',
    ax=ax,
    cmap='RdYlGn',
    vmin=0.53,
    vmax=0.63,
    legend=True,
    missing_kwds={'color': 'lightgray'},
    legend_kwds={'label': 'Mood Score (Red = Dark, Green = Upbeat)', 'shrink': 0.6}
)

ax.set_xlim(-25, 45)
ax.set_ylim(34, 72)
ax.set_title('Musical Mood Score Across Europe (2017-2018)', fontsize=16)
ax.axis('off')

plt.tight_layout()

# Add country names
for idx, row in europe_map.iterrows():
    if row['geometry'] is not None and row['mood_score'] > 0:
        ax.annotate(
            row['NAME'],
            xy=(row['geometry'].centroid.x, row['geometry'].centroid.y),
            fontsize=10,
            ha='center',
            color='black'
        )
plt.show()

# %%
# Calculate mood score for each year separately
country_2017 = df_europe[df_europe['year'] == 2017].groupby('region')[['af_energy', 'af_valence']].mean().round(3)
country_2017['mood_score'] = ((country_2017['af_energy'] + country_2017['af_valence']) / 2).round(3)

country_2018 = df_europe[df_europe['year'] == 2018].groupby('region')[['af_energy', 'af_valence']].mean().round(3)
country_2018['mood_score'] = ((country_2018['af_energy'] + country_2018['af_valence']) / 2).round(3)

# Compare side by side
stability = country_2017[['mood_score']].join(country_2018[['mood_score']], lsuffix='_2017', rsuffix='_2018')
stability['difference'] = (stability['mood_score_2018'] - stability['mood_score_2017']).round(3)
stability['stable'] = stability['difference'].abs() < 0.02

print(stability.sort_values('difference'))
# Out:
#                 mood_score_2017  mood_score_2018  difference  stable
# region
# Norway                    0.567            0.535      -0.032   False
# Spain                     0.638            0.614      -0.024   False
# Ireland                   0.576            0.559      -0.017    True
# Italy                     0.589            0.575      -0.014    True
# Greece                    0.563            0.550      -0.013    True
# Finland                   0.615            0.603      -0.012    True
# United Kingdom            0.581            0.570      -0.011    True
# Lithuania                 0.553            0.544      -0.009    True
# Latvia                    0.546            0.540      -0.006    True
# Estonia                   0.549            0.544      -0.005    True
# Denmark                   0.562            0.560      -0.002    True
# Hungary                   0.593            0.592      -0.001    True
# Czech Republic            0.570            0.570       0.000    True
# Iceland                   0.542            0.544       0.002    True
# Germany                   0.584            0.591       0.007    True
# Austria                   0.582            0.590       0.008    True
# Sweden                    0.556            0.564       0.008    True
# Slovakia                  0.564            0.572       0.008    True
# Netherlands               0.590            0.598       0.008    True
# Portugal                  0.554            0.564       0.010    True
# Switzerland               0.570            0.582       0.012    True
# France                    0.568            0.584       0.016    True
# Belgium                   0.556            0.573       0.017    True
# Poland                    0.556            0.582       0.026   False
# Bulgaria                  0.560              NaN         NaN   False
# Luxembourg                0.584              NaN         NaN   False

# %%
fig, ax = plt.subplots(figsize=(10, 8))

colors = stability['stable'].map({True: 'steelblue', False: 'coral'})
ax.barh(stability.index, stability['difference'], color=colors)
ax.axvline(0, color='black', linewidth=0.8)
ax.axvline(0.02, color='gray', linestyle='--', alpha=0.5, label='Stability threshold (+0.02)')
ax.axvline(-0.02, color='gray', linestyle='--', alpha=0.5, label='Stability threshold (-0.02)')
ax.set_title('Mood Score Change from 2017 to 2018 by Country', fontsize=14)
ax.set_xlabel('Change in Mood Score')
ax.legend()

plt.tight_layout()
plt.show()
